# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('clean.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65239 entries, 0 to 65238
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Location              65239 non-null  object
#  1   Carpet Area           34582 non-null  float64
#  2   Transaction           65239 non-null  object
#  3   Furnishing            65239 non-null  object
#  4   Facing                65239 non-null  object
#  5   Society               65239 non-null  object
#  6   Bathroom              65239 non-null  object
#  7   Balcony               65239 non-null  object
#  8   Ownership             65239 non-null  object
#  9   Area(in sqft)         59623 non-null  float64
#  10  BHK                   65239 non-null  object
#  11  FlatFloor             62745 non-null  float64
#  12  TotalFloors           62698 non-null  float64
#  13  Basement              65239 non-null  bool
#  14  Main Road             65239 non-null  object
#  15  Garden/Park           65239 non-null  object
#  16  Pool                  65239 non-null  object
#  17  ParkingNumbers        65239 non-null  int64
#  18  Parking Type          65239 non-null  object
#  19  SalePrice(in Crores)  62432 non-null  float64
#  20  latitude              65239 non-null  float64
#  21  longitude             65239 non-null  float64
#  22  state                 65239 non-null  object
# dtypes: bool(1), float64(7), int64(1), object(14)
# memory usage: 11.0+ MB

# %%
df=df.drop(columns=['Facing','Society','Ownership','Basement','Main Road','Garden/Park','Pool','latitude','longitude',
                    'Area(in sqft)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65239 entries, 0 to 65238
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Location              65239 non-null  object
#  1   Carpet Area           34582 non-null  float64
#  2   Transaction           65239 non-null  object
#  3   Furnishing            65239 non-null  object
#  4   Bathroom              65239 non-null  object
#  5   Balcony               65239 non-null  object
#  6   BHK                   65239 non-null  object
#  7   FlatFloor             62745 non-null  float64
#  8   TotalFloors           62698 non-null  float64
#  9   ParkingNumbers        65239 non-null  int64
#  10  Parking Type          65239 non-null  object
#  11  SalePrice(in Crores)  62432 non-null  float64
#  12  state                 65239 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 6.5+ MB

# %%
df.isnull().sum()
# Out:
# Location                    0
# Carpet Area             30657
# Transaction                 0
# Furnishing                  0
# Bathroom                    0
# Balcony                     0
# BHK                         0
# FlatFloor                2494
# TotalFloors              2541
# ParkingNumbers              0
# Parking Type                0
# SalePrice(in Crores)     2807
# state                       0
# dtype: int64

# %%
df['Carpet Area']=df['Carpet Area'].fillna(df['Carpet Area'].mean())

# %%
df['FlatFloor']=df['FlatFloor'].fillna(df['FlatFloor'].mean())

# %%
df['TotalFloors']=df['TotalFloors'].fillna(df['TotalFloors'].mean())

# %%
df.isnull().sum()
# Out:
# Location                   0
# Carpet Area                0
# Transaction                0
# Furnishing                 0
# Bathroom                   0
# Balcony                    0
# BHK                        0
# FlatFloor                  0
# TotalFloors                0
# ParkingNumbers             0
# Parking Type               0
# SalePrice(in Crores)    2807
# state                      0
# dtype: int64

# %%
df=df.dropna(subset=['SalePrice(in Crores)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62432 entries, 0 to 65238
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Location              62432 non-null  object
#  1   Carpet Area           62432 non-null  float64
#  2   Transaction           62432 non-null  object
#  3   Furnishing            62432 non-null  object
#  4   Bathroom              62432 non-null  object
#  5   Balcony               62432 non-null  object
#  6   BHK                   62432 non-null  object
#  7   FlatFloor             62432 non-null  float64
#  8   TotalFloors           62432 non-null  float64
#  9   ParkingNumbers        62432 non-null  int64
#  10  Parking Type          62432 non-null  object
#  11  SalePrice(in Crores)  62432 non-null  float64
#  12  state                 62432 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 6.7+ MB

# %%
df['Bathroom']=pd.to_numeric(df['Bathroom'],errors='coerce')

# %%
df.dropna(subset=['Bathroom'],inplace=True)

# %%
df['Balcony']=pd.to_numeric(df['Balcony'],errors='coerce')

# %%
df.dropna(subset=['Balcony'],inplace=True)

# %%
df['BHK']=pd.to_numeric(df['BHK'],errors='coerce')

# %%
df.dropna(subset=['BHK'],inplace=True)

# %%
df.duplicated().value_counts()
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59853 entries, 0 to 65238
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Location              59853 non-null  object
#  1   Carpet Area           59853 non-null  float64
#  2   Transaction           59853 non-null  object
#  3   Furnishing            59853 non-null  object
#  4   Bathroom              59853 non-null  float64
#  5   Balcony               59853 non-null  float64
#  6   BHK                   59853 non-null  float64
#  7   FlatFloor             59853 non-null  float64
#  8   TotalFloors           59853 non-null  float64
#  9   ParkingNumbers        59853 non-null  int64
#  10  Parking Type          59853 non-null  object
#  11  SalePrice(in Crores)  59853 non-null  float64
#  12  state                 59853 non-null  object
# dtypes: float64(7), int64(1), object(5)
# memory usage: 6.4+ MB

# %%
df['Bathroom'].value_counts()
# Out:
# Bathroom
# 2.0     30769
# 3.0     17695
# 1.0      5478
# 4.0      4518
# 5.0      1182
# 6.0       164
# 7.0        23
# 8.0        10
# 10.0        9
# 9.0         5
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          Carpet Area      Bathroom       Balcony           BHK     FlatFloor  \
# count   59853.000000  59853.000000  59853.000000  59853.000000  59853.000000
# mean     1323.775672      2.430004      1.548627      2.572870      4.218984
# std      3973.979443      0.868982      1.258930      0.820458      4.150574
# min         1.000000      1.000000      0.000000      1.000000     -2.000000
# 25%      1061.000000      2.000000      0.000000      2.000000      2.000000
# 50%      1319.798074      2.000000      2.000000      3.000000      3.000000
# 75%      1319.798074      3.000000      2.000000      3.000000      5.000000
# max    709222.000000     10.000000     10.000000     10.000000    200.000000
#
#         TotalFloors  ParkingNumbers  SalePrice(in Crores)
# count  59853.000000    59853.000000          59853.000000
# mean       8.349804        1.663977              1.042465
# std        6.445168       21.905343              6.524426
# min        1.000000        0.000000              0.010000
# 25%        4.000000        0.000000              0.410000
# 50%        6.000000        0.000000              0.650000
# 75%       12.000000        1.000000              1.050000
# max      200.000000      999.000000           1400.300000

# %%
import matplotlib.pyplot as plt

# %%
df['SalePrice(in Crores)'].min()
# Out:
# np.float64(0.01)

# %%
df['SalePrice(in Crores)'].max()
# Out:
# np.float64(1400.3)

# %%
df = df[df['SalePrice(in Crores)'] != 1400.3]

# %%
df['SalePrice(in Crores)'].max()
# Out:
# np.float64(510.04)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59852 entries, 0 to 65238
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Location              59852 non-null  object
#  1   Carpet Area           59852 non-null  float64
#  2   Transaction           59852 non-null  object
#  3   Furnishing            59852 non-null  object
#  4   Bathroom              59852 non-null  float64
#  5   Balcony               59852 non-null  float64
#  6   BHK                   59852 non-null  float64
#  7   FlatFloor             59852 non-null  float64
#  8   TotalFloors           59852 non-null  float64
#  9   ParkingNumbers        59852 non-null  int64
#  10  Parking Type          59852 non-null  object
#  11  SalePrice(in Crores)  59852 non-null  float64
#  12  state                 59852 non-null  object
# dtypes: float64(7), int64(1), object(5)
# memory usage: 6.4+ MB

# %%
df.to_csv('cleaned-home-data.csv',index=False)
